# %%
import sys
print(sys.version)
# Out:
# 3.13.12 | packaged by Anaconda, Inc. | (main, Feb 24 2026, 16:05:56) [MSC v.1942 64 bit (AMD64)]

# %%
# pip install khmerocr-tools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
